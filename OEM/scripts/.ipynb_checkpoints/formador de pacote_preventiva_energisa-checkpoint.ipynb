# %% [markdown]
#  # Importar arquivos para leitura

# %%
import pandas as pd
import os

# %%
base_sip_oem = pd.read_excel(r"C:\Users\helym\projetos_python\jupyter\OEM\content\base_sip_Concluido.xlsx")
#df_intelbras = pd.read_excel(r"E:\ACRÉSCIMOS PREVENTIVA JUNHO 3ª REMESSA.xlsx")

# %%
base_sip_oem = base_sip_oem[['IDSIGFI','NUMOS','NOMECLIENTE','CPF','CODIGOENERGISA','UC','TIPODESIGFI','OBRA','ROTA','EXECUTOR','LATLONCON','TIPOCAUSA','DTCONCLUSAO','ENDERECO','MUNICIPIO']]

# %%
print(base_sip_oem.shape)
#print(df_intelbras.shape)
# Out:
# (8515, 15)

# %% [markdown]
# # Realizar leitura de arquivos  .pdf  dentro das pastas correspondente

# %%
diretorio_lote = r"C:\Users\helym\OneDrive - ONE ENGENHARIA INDUSTRIA E COMERCIO LTDA\OeM\OeM\00-INTELBRAS\000_Relatórios de Campo\001 RELATORIOS ENVIADOS\AC\0.0-PREVENTIVA\1ªTRACHE\2024\LOTE_17\3ªREMESSA"
#"C:\Users\OneEngInst\OneDrive - ONE ENGENHARIA INDUSTRIA E COMERCIO LTDA\OeM\OeM\00-INTELBRAS\000_Relatórios de Campo\001 RELATORIOS ENVIADOS\0.0-PREVENTIVA\1ªTRACHE\2024\LOTE_16\3ªREMESSA"

# %%
# listando os arquivos dentro da pasta.
arquivos_pdf = []
for raiz, diretorios, arquivos in os.walk(diretorio_lote):
    for arquivo in arquivos:
        if arquivo.endswith('.pdf'):
            arquivos_pdf.append(os.path.join(raiz, arquivo))

lista_pdf = pd.DataFrame(arquivos_pdf, columns=['NUMOS'])
lista_pdf['NUMOS'] = lista_pdf['NUMOS'].apply(lambda x: x[-22:-10]).astype('int64')
contagem_arquivos = lista_pdf['NUMOS'].unique().shape[0]
dataset = lista_pdf.merge(base_sip_oem, left_on='NUMOS', right_on='NUMOS', how='left')

# %%
dataset[['LATLONCON']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LATLONCON  15 non-null     object
# dtypes: object(1)
# memory usage: 252.0+ bytes

# %%
# Rastrear duplicidade e soma-las.
dataset['NUMOS'].duplicated().sum()
# Out:
# 0

# %%
dataset['NUMOS'].count()
# Out:
# 15

# %%
def encontrar_duplicados(dataset):
    duplicados = dataset[dataset.duplicated(subset='NUMOS')]
    return duplicados['NUMOS']

# Exemplo de uso
duplicados = encontrar_duplicados(dataset)
print(duplicados)
# Out:
# Series([], Name: NUMOS, dtype: int64)

# %% [markdown]
# # Realizar a mesclagem com número de OS entre os dados da base do sistema com a lista de arquivos encontrados na pasta

# %%
#dataset[['LATITUDE', 'LONGITUDE','ERRO_1','ERRO_2']] = dataset['LATLONCON'].apply(lambda x: pd.Series(x.split(',')))#,'ERRO_1','ERRO_2'
def split_latlon(x):
    if isinstance(x, str):
        return pd.Series(x.split(','))
    else:
        #Se não for uma string, retorna NaN ou valores padrão, dependendo do que você deseja
        return pd.Series([pd.NaT, pd.NaT])

# Aplica a função split_latlon à coluna 'LATLONCON'
dataset[['LATITUDE', 'LONGITUDE']] = dataset['LATLONCON'].apply(split_latlon)#,'erro_1','erro_2'

# Converta as colunas 'LATITUDE' e 'LONGITUDE' para números, se necessário
#dataset[['LATITUDE', 'LONGITUDE']] = dataset[['LATITUDE', 'LONGITUDE']].apply(pd.to_numeric, errors='coerce')

dataset= dataset[['IDSIGFI','UC','OBRA','NOMECLIENTE','CPF','ENDERECO','MUNICIPIO','DTCONCLUSAO','TIPOCAUSA','ROTA','EXECUTOR','TIPODESIGFI','LATITUDE','LONGITUDE','NUMOS']]#,'NUMOS'
lote = dataset.rename(columns={'IDSIGFI':'CÓDIGO ONE','NOMECLIENTE':'NOME DO CLIENTE','CODIGOENERGISA': 'CÓDIGO','UC': 'NÚM.DA UC',
                               'OBRA':'NÚM.DA OBRA','EXECUTOR':'EQUIPE EXECUTORA',
                              'TIPODESIGFI': 'TIPO/SIGFI','TIPOCAUSA':'PREVENTIVA','DTCONCLUSAO':'DATA ATENDIMENTO'})

replacements1 = {'ONEOM001':'EQ.1','ONEOM002':'EQ.2','ONEOM003':'EQ.3','ONEOM004':'EQ.4','ONEOM005':'EQ.5','ONEOM006':'EQ.6','ONEOM007':'EQ.7',
                 'ONEOM008':'EQ.8','ONEOM009':'EQ.9','ONEOM010':'EQ.10','ONEOM011':'EQ.11','ONEOM012':'EQ.12','ONEOM013':'EQ.13','ONEOM014':'EQ.14',
                 'ONEOM015':'EQ.15'}
lote['EQUIPE EXECUTORA'] = lote['EQUIPE EXECUTORA'].replace(replacements1)

replacements2 = {'MANUT PREVENTIVA 1A':'1ªPREVENTIVA','MANUT PREVENTIVA 2A':'2ªPREVENTIVA','MANUT PREVENTIVA 3A':'3ªPREVENTIVA',
                 'MANUT PREVENTIVA 4A':'4ªPREVENTIVA','MANUT PREVENTIVA 5A':'5ªPREVENTIVA'}
lote['PREVENTIVA'] = lote['PREVENTIVA'].replace(replacements2)

replacements3 = {'CRUZEIRO DO SUL':'CRUZEIRO DO SUL','FEIJO':'CRUZEIRO DO SUL','JORDAO':'CRUZEIRO DO SUL',
                 'JURUA':'CRUZEIRO DO SUL','MARECHAL THAUMATURGO':'CRUZEIRO DO SUL','MANCIO LIMA':'CRUZEIRO DO SUL',
                'PORTO WALTER':'CRUZEIRO DO SUL','RODRIGUES ALVES':'CRUZEIRO DO SUL','TARAUACA':'CRUZEIRO DO SUL',
                'ASSIS BRASIL':'BRASILÉIA','SENA MADUREIRA':'RIO BRANCO','RIO AZUL':'CRUZEIRO DO SUL','xxxxxxxxx':'xxxxxxxxxx'}

lote['REGIONAL'] = lote['MUNICIPIO'].replace(replacements3)

lote = lote[['CÓDIGO ONE', 'NÚM.DA UC', 'NÚM.DA OBRA', 'NOME DO CLIENTE', 'CPF',
       'ENDERECO', 'MUNICIPIO','REGIONAL', 'DATA ATENDIMENTO', 'PREVENTIVA', 'ROTA',
       'EQUIPE EXECUTORA', 'TIPO/SIGFI', 'LATITUDE', 'LONGITUDE', 'NUMOS']]

# %%
lote
# Out:
#     CÓDIGO ONE  NÚM.DA UC  NÚM.DA OBRA  \
# 0        14843   652426.0  212201063.0
# 1        14279   655046.0  212201479.0
# 2        14458   655053.0  212201483.0
# 3        14369   655060.0  212201502.0
# 4        14455   656059.0  212201791.0
# 5        14245   656894.0  212201565.0
# 6        14275   656896.0  212201583.0
# 7        14457   656909.0  212201621.0
# 8        14277   656926.0  212201729.0
# 9        14239   656949.0  212201830.0
# 10       14367   658175.0  212201562.0
# 11       14368   658181.0  212201793.0
# 12       14401   659050.0  212201828.0
# 13       14276   660374.0  212201831.0
# 14       14278   684557.0  212201799.0
#
#                              NOME DO CLIENTE             CPF  \
# 0                        MARIA CLARICE SOUZA  068.229.112-94
# 1                    EDIVALDO FERREIRA GOMES  824.080.092-00
# 2                 MARIA TEREZINHA DE ALMEIDA  602.757.312-00
# 3                     MARALENE LIMA DA SILVA  709.933.192-20
# 4            BARTOLOMEU MACHADO DA CONCEIÇÃO  709.957.702-63
# 5   FRANCISCO DAS CHAGAS FERREIRA DOS SANTOS  709.739.462-53
# 6         MARIA DA LIBERDADE DA SILVA VIEIRA  840.312.802-97
# 7             MANOEL GILMAR TEIXEIRA DE LIMA  006.989.802-20
# 8           HIDELBERTO RICARDO DO NASCIMENTO  562.157.462-15
# 9                    LUZIVALDO ALVES DE LIMA  000.950.712-45
# 10               ANTONIO FERREIRA DOS SANTOS  954.893.632-15
# 11          JOAO RENE DE SOUZA DO NASCIMENTO  065.566.812-88
# 12                   ANTONIO PEREIRA MACHADO  699.550.772-04
# 13            MARIA SABINA DA SILVA FERREIRA  069.788.112-11
# 14         MARIA DIONEIDE PEREIRA DE ANDRADE  035.611.452-05
#
#                                              ENDERECO MUNICIPIO  \
# 0   RIO TARAUACA, SERINGAL APODIR    RIO TARAUACA,...  TARAUACA
# 1   SERINGAL MATO GROSSO S/N COLONIA ESPERANCA CEN...    JORDAO
# 2   SERINGAL EXTREMA S/N RIO TARAUACA CENTRO SERIN...    JORDAO
# 3   SERINGAL TABOCAL S/N COLONIA PELOTA CENTRO  SE...  TARAUACA
# 4   SERINGAL BOA VISTA S/N RIO TARAUACA CENTRO SER...    JORDAO
# 5   SERINGAL REDENCAO S/N DESCENDO RIO TARAUACA CE...    JORDAO
# 6   SERINGAL PALESTINA S/N COLONIA NOVA FAZENDA CE...  TARAUACA
# 7   SERINGAL TABOCAL S/N RIO TARAUACA CENTRO SERIN...    JORDAO
# 8   SERINGAL MATO GROSSO S/N  COLONIA NOVA VIDA CE...    JORDAO
# 9   SERINGAL SAO LUIZ S/N DESCENDO O RIO TARAUACA ...  TARAUACA
# 10  SERINGAL REDENCAO S/N COLONIA ESCONDIDO CENTRO...    JORDAO
# 11  SERINGAL NOVA VIDA S/N COLONIA MATO GROSSO CEN...    JORDAO
# 12      SANTA CRUZ S/N RIO TARAUACA CENTRO SANTA CRUZ  TARAUACA
# 13  SERINGAL TABOCAL S/N ALTO TARAUACA CENTRO  SER...  TARAUACA
# 14  SERINGAL MATO GROSSO S/N RIO TARAUACA CENTRO S...    JORDAO
#
#            REGIONAL    DATA ATENDIMENTO     PREVENTIVA  ROTA EQUIPE EXECUTORA  \
# 0   CRUZEIRO DO SUL 2024-05-06 09:16:00  INTERMITENCIA   7.0             EQ.4
# 1   CRUZEIRO DO SUL 2024-05-03 10:16:00   4ªPREVENTIVA   8.0             EQ.8
# 2   CRUZEIRO DO SUL 2024-05-03 11:23:00   4ªPREVENTIVA   8.0             EQ.8
# 3   CRUZEIRO DO SUL 2024-05-03 14:44:00   4ªPREVENTIVA   8.0             EQ.8
# 4   CRUZEIRO DO SUL 2024-05-04 08:20:00   4ªPREVENTIVA   8.0             EQ.8
# 5   CRUZEIRO DO SUL 2024-05-04 13:27:00   4ªPREVENTIVA   8.0             EQ.8
# 6   CRUZEIRO DO SUL 2024-05-04 14:24:00   4ªPREVENTIVA   8.0             EQ.8
# 7   CRUZEIRO DO SUL 2024-05-03 12:29:00   4ªPREVENTIVA   8.0             EQ.8
# 8   CRUZEIRO DO SUL 2024-05-04 10:20:00   4ªPREVENTIVA   8.0             EQ.8
# 9   CRUZEIRO DO SUL 2024-05-05 07:26:00   4ªPREVENTIVA   8.0             EQ.8
# 10  CRUZEIRO DO SUL 2024-05-04 12:30:00   4ªPREVENTIVA   8.0             EQ.8
# 11  CRUZEIRO DO SUL 2024-05-04 11:23:00   4ªPREVENTIVA   8.0             EQ.8
# 12  CRUZEIRO DO SUL 2024-05-04 09:14:00   4ªPREVENTIVA   8.0             EQ.8
# 13  CRUZEIRO DO SUL 2024-05-03 09:09:00   4ªPREVENTIVA   8.0             EQ.8
# 14  CRUZEIRO DO SUL 2024-05-03 13:45:00   4ªPREVENTIVA   8.0             EQ.8
#
#    TIPO/SIGFI            LATITUDE           LONGITUDE         NUMOS
# 0     SIGFI80         -8.28753351        -71.08635655  202400030815
# 1     SIGFI45  -8.731613333333334  -71.71451333333333  202400021319
# 2     SIGFI80  -8.720085000000001  -71.71393333333334  202400021327
# 3     SIGFI80  -8.718508333333334  -71.69476166666666  202400021350
# 4     SIGFI80  -8.718561666666666          -71.688025  202400021368
# 5     SIGFI80  -8.692350000000001  -71.63591333333333  202400021517
# 6     SIGFI80           -8.687595  -71.62647666666666  202400021509
# 7     SIGFI80  -8.727153333333332  -71.69723333333333  202400021335
# 8     SIGFI80  -8.719256666666666          -71.677805  202400021533
# 9     SIGFI45  -8.668198333333333  -71.55647333333333  202400020790
# 10    SIGFI80  -8.709251666666667           -71.65968  202400021525
# 11    SIGFI80           -8.718285  -71.67466833333333  202400021541
# 12    SIGFI80           -8.715005  -71.68269000000001  202400021376
# 13    SIGFI80  -8.753873333333333          -71.741195  202400021301
# 14    SIGFI80  -8.723234999999999  -71.69254166666666  202400021343

# %%
# Salvando a planilha( .xlsx)
dataframe_excel = pd.ExcelWriter(r"C:\Users\helym\projetos_python\jupyter\OEM\output\1ºtrache_preventiva_lote17_1ªremessa_2024.xlsx")
lote.to_excel(dataframe_excel, index=False)
dataframe_excel.close()
