# %% [markdown]
#  # Importar arquivos para leitura

# %%
import pandas as pd
import os

# %%
base_sip_oem = pd.read_excel(r"D:\OEM\content\base_sip_Concluido.xlsx")
#df_intelbras = pd.read_excel(r"E:\ACRÉSCIMOS PREVENTIVA JUNHO 3ª REMESSA.xlsx")

# %%
base_sip_oem = base_sip_oem[['IDSIGFI','NUMOS','NOMECLIENTE','CPF','CODIGOENERGISA','UC','TIPODESIGFI','OBRA','ROTA','EXECUTOR','LATLONCON','TIPOCAUSA','DTCONCLUSAO','ENDERECO','MUNICIPIO']]

# %%
print(base_sip_oem.shape)
#print(df_intelbras.shape)
# Out:
# (8577, 15)

# %% [markdown]
# # Realizar leitura de arquivos  .pdf  dentro das pastas correspondente

# %%
diretorio_lote = r"C:\Users\OneEngInst\OneDrive - ONE ENGENHARIA INDUSTRIA E COMERCIO LTDA\OeM\OeM\00-INTELBRAS\000_Relatórios de Campo\001 RELATORIOS ENVIADOS\AC\0_0-PREVENTIVA\1ªTRACHE\2024\LOTE_17\3ªREMESSA"
#"C:\Users\OneEngInst\OneDrive - ONE ENGENHARIA INDUSTRIA E COMERCIO LTDA\OeM\OeM\00-INTELBRAS\000_Relatórios de Campo\001 RELATORIOS ENVIADOS\0.0-PREVENTIVA\1ªTRACHE\2024\LOTE_16\3ªREMESSA"

# %%
# listando os arquivos dentro da pasta.
arquivos_pdf = []
for raiz, diretorios, arquivos in os.walk(diretorio_lote):
    for arquivo in arquivos:
        if arquivo.endswith('.pdf'):
            arquivos_pdf.append(os.path.join(raiz, arquivo))

lista_pdf = pd.DataFrame(arquivos_pdf, columns=['NUMOS'])
lista_pdf['NUMOS'] = lista_pdf['NUMOS'].apply(lambda x: x[-22:-10]).astype('int64')
contagem_arquivos = lista_pdf['NUMOS'].unique().shape[0]
dataset = lista_pdf.merge(base_sip_oem, left_on='NUMOS', right_on='NUMOS', how='left')

# %%
dataset[['LATLONCON']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LATLONCON  19 non-null     object
# dtypes: object(1)
# memory usage: 284.0+ bytes

# %%
# Rastrear duplicidade e soma-las.
dataset['NUMOS'].duplicated().sum()
# Out:
# 0

# %%
dataset['NUMOS'].count()
# Out:
# 19

# %%
def encontrar_duplicados(dataset):
    duplicados = dataset[dataset.duplicated(subset='NUMOS')]
    return duplicados['NUMOS']

# Exemplo de uso
duplicados = encontrar_duplicados(dataset)
print(duplicados)
# Out:
# Series([], Name: NUMOS, dtype: int64)

# %% [markdown]
# # Realizar a mesclagem com número de OS entre os dados da base do sistema com a lista de arquivos encontrados na pasta

# %%
#dataset[['LATITUDE', 'LONGITUDE','ERRO_1','ERRO_2']] = dataset['LATLONCON'].apply(lambda x: pd.Series(x.split(',')))#,'ERRO_1','ERRO_2'
def split_latlon(x):
    if isinstance(x, str):
        return pd.Series(x.split(','))
    else:
        #Se não for uma string, retorna NaN ou valores padrão, dependendo do que você deseja
        return pd.Series([pd.NaT, pd.NaT])

# Aplica a função split_latlon à coluna 'LATLONCON'
dataset[['LATITUDE', 'LONGITUDE']] = dataset['LATLONCON'].apply(split_latlon)#,'erro_1','erro_2'

# Converta as colunas 'LATITUDE' e 'LONGITUDE' para números, se necessário
#dataset[['LATITUDE', 'LONGITUDE']] = dataset[['LATITUDE', 'LONGITUDE']].apply(pd.to_numeric, errors='coerce')

dataset= dataset[['IDSIGFI','UC','OBRA','NOMECLIENTE','CPF','ENDERECO','MUNICIPIO','DTCONCLUSAO','TIPOCAUSA','ROTA','EXECUTOR','TIPODESIGFI','LATITUDE','LONGITUDE','NUMOS']]#,'NUMOS'
lote = dataset.rename(columns={'IDSIGFI':'CÓDIGO ONE','NOMECLIENTE':'NOME DO CLIENTE','CODIGOENERGISA': 'CÓDIGO','UC': 'NÚM.DA UC',
                               'OBRA':'NÚM.DA OBRA','EXECUTOR':'EQUIPE EXECUTORA',
                              'TIPODESIGFI': 'TIPO/SIGFI','TIPOCAUSA':'PREVENTIVA','DTCONCLUSAO':'DATA ATENDIMENTO'})

replacements1 = {'ONEOM001':'EQ.1','ONEOM002':'EQ.2','ONEOM003':'EQ.3','ONEOM004':'EQ.4','ONEOM005':'EQ.5','ONEOM006':'EQ.6','ONEOM007':'EQ.7',
                 'ONEOM008':'EQ.8','ONEOM009':'EQ.9','ONEOM010':'EQ.10','ONEOM011':'EQ.11','ONEOM012':'EQ.12','ONEOM013':'EQ.13','ONEOM014':'EQ.14',
                 'ONEOM015':'EQ.15'}
lote['EQUIPE EXECUTORA'] = lote['EQUIPE EXECUTORA'].replace(replacements1)

replacements2 = {'MANUT PREVENTIVA 1A':'1ªPREVENTIVA','MANUT PREVENTIVA 2A':'2ªPREVENTIVA','MANUT PREVENTIVA 3A':'3ªPREVENTIVA',
                 'MANUT PREVENTIVA 4A':'4ªPREVENTIVA','MANUT PREVENTIVA 5A':'5ªPREVENTIVA'}
lote['PREVENTIVA'] = lote['PREVENTIVA'].replace(replacements2)

replacements3 = {'CRUZEIRO DO SUL':'CRUZEIRO DO SUL','FEIJO':'CRUZEIRO DO SUL','JORDAO':'CRUZEIRO DO SUL',
                 'JURUA':'CRUZEIRO DO SUL','MARECHAL THAUMATURGO':'CRUZEIRO DO SUL','MANCIO LIMA':'CRUZEIRO DO SUL',
                'PORTO WALTER':'CRUZEIRO DO SUL','RODRIGUES ALVES':'CRUZEIRO DO SUL','TARAUACA':'CRUZEIRO DO SUL',
                'ASSIS BRASIL':'BRASILÉIA','SENA MADUREIRA':'RIO BRANCO','RIO AZUL':'CRUZEIRO DO SUL','xxxxxxxxx':'xxxxxxxxxx'}

lote['REGIONAL'] = lote['MUNICIPIO'].replace(replacements3)

lote = lote[['CÓDIGO ONE', 'NÚM.DA UC', 'NÚM.DA OBRA', 'NOME DO CLIENTE', 'CPF',
       'ENDERECO', 'MUNICIPIO','REGIONAL', 'DATA ATENDIMENTO', 'PREVENTIVA', 'ROTA',
       'EQUIPE EXECUTORA', 'TIPO/SIGFI', 'LATITUDE', 'LONGITUDE', 'NUMOS']]

# %%
lote
# Out:
#     CÓDIGO ONE  NÚM.DA UC  NÚM.DA OBRA                       NOME DO CLIENTE  \
# 0        15091   654905.0  212201489.0             RONISON SOARES DE AZEVEDO
# 1        14548   661038.0  112203478.0      ANTONIO JANES GADELHA DOS SANTOS
# 2        14177   661772.0  312200827.0          OBERLENE DE OLIVEIRA PEREIRA
# 3        14210   661794.0  312200837.0           RONALDO RODRIGUES DE MORAIS
# 4        14593   661928.0  112203448.0  MARIA DA CONCEICAO DE SIQUEIRA MOURA
# 5        15761   669424.0  312200920.0              RAIMUNDO PEREIRA DE LIMA
# 6        15483   669523.0  212202462.0                MARIA VIEIRA DOS ANJOS
# 7        15785   688736.0          NaN      MARIA EDILENE DO SACRAMENTO LIMA
# 8        15791   688737.0          NaN       MARIA GESSILENE SACRAMENTO LIMA
# 9        15773   688744.0          NaN                           MARIA GOMES
# 10       15789   688749.0          NaN            MARIA JOSÉ TIMÓTEO DE LIMA
# 11       15775   688752.0          NaN          MARIA MARILENE GOMES DE LIMA
# 12       15783   688758.0          NaN                ROSA BERNARDO DA COSTA
# 13       15771   688886.0          NaN       FRANCISCO DAS CHAGAS GOMES LIMA
# 14       15765   688892.0          NaN          JOSE ADAILDO TORRES DA SILVA
# 15       15787   688897.0          NaN       JOSÉ MAURO DE AMORIM DOS SANTOS
# 16       15797   688899.0          NaN            JOSEVAN QUINELATO DA SILVA
# 17       15767   688906.0          NaN         MILTON DO SACRAMENTO FERREIRA
# 18       15781   688912.0          NaN      RAIMUNDO NONATO DOS SANTOS SILVA
#
#                CPF                                           ENDERECO  \
# 0   084.526.512-10  RIO JURUA COMUNIDADE ADÃO E EVA    RIO JURUA C...
# 1   008.808.062-57  SERINGAL BELA VISTA S/N RIO CAETE CENTRO SERIN...
# 2   687.272.832-91  RM CATIANÃ  SERINGAL GUANABARA S/N COLOCACAO C...
# 3   050.291.262-60  RM ICURIÃ SERINGAL ICURIÃ S/N COLONIA DEUS PRO...
# 4   752.738.452-20  SERINGAL GRANJA GRANDE S/N RIO CAETE CENTRO SE...
# 5   326.135.802-59  RM AMAPÁ.  SERINGAL SANTA ANA    RM AMAPÁ.  SE...
# 6   942.006.372-00                 SERINGAL AJUBIM    SERINGAL AJUBIM
# 7   047.210.882-48  BR 364. RIO TAUARI.  COLÔNIA SANTA CRUZ    BR ...
# 8       5729235208  BR 364. RIO TAUARI.  COLÔNIA NOVA ALIANÇA    B...
# 9   623.435.052-68  BR 364. RIO TAUARI. COLÔNIA VIDA NOVA    BR 36...
# 10  535.931.542-34  BR 364    RIO TAUARI   COLÔNIA SANTA CRUZ    B...
# 11  052.749.732-05  BR 364. RIO TAUARI. COLÔNIA MORADA NOVA    BR ...
# 12  012.208.272-90  BR 364. RIO TAUARI. COLÔNIA SÃO FRANCISCO    B...
# 13  699.631.932-34  BR 364. RIO TAUARI. COLÔNIA SÃO FRANCISCO    B...
# 14  966.162.452-68  BR.364. RIO TAUARI . SERINGAL LAVRA    BR.364....
# 15  699.701.812-20  BR 364. RIO TAUARI. COLÔNIA SANTA CRUZ    BR 3...
# 16  049.948.032-50  BR 364. RIO TAUARI.  COLÔNIA BOA VISTA    BR 3...
# 17  966.165.802-10  BR 364. RIO TAUARI  COLÔNIA MORADA NOVA    BR ...
# 18  078.562.982-44  BR 364. RIO TAUARI.  COLÔNIA SÃO FRANCISCO    ...
#
#                MUNICIPIO         REGIONAL    DATA ATENDIMENTO  \
# 0   MARECHAL THAUMATURGO  CRUZEIRO DO SUL 2024-05-11 10:23:00
# 1         SENA MADUREIRA       RIO BRANCO 2024-05-09 10:27:00
# 2           ASSIS BRASIL        BRASILÉIA 2024-05-08 12:47:00
# 3           ASSIS BRASIL        BRASILÉIA 2024-05-07 16:44:00
# 4         SENA MADUREIRA       RIO BRANCO 2024-05-08 09:55:00
# 5           ASSIS BRASIL        BRASILÉIA 2024-05-09 11:20:00
# 6                  FEIJO  CRUZEIRO DO SUL 2024-05-09 17:16:00
# 7               TARAUACA  CRUZEIRO DO SUL 2024-04-26 09:03:00
# 8               TARAUACA  CRUZEIRO DO SUL 2024-04-25 16:07:00
# 9               TARAUACA  CRUZEIRO DO SUL 2024-04-26 16:58:00
# 10              TARAUACA  CRUZEIRO DO SUL 2024-04-26 10:39:00
# 11              TARAUACA  CRUZEIRO DO SUL 2024-04-27 08:08:00
# 12              TARAUACA  CRUZEIRO DO SUL 2024-04-26 12:47:00
# 13              TARAUACA  CRUZEIRO DO SUL 2024-04-27 11:01:00
# 14              TARAUACA  CRUZEIRO DO SUL 2024-04-27 14:55:00
# 15              TARAUACA  CRUZEIRO DO SUL 2024-04-26 09:53:00
# 16              TARAUACA  CRUZEIRO DO SUL 2024-04-25 09:51:00
# 17              TARAUACA  CRUZEIRO DO SUL 2024-04-27 16:03:00
# 18              TARAUACA  CRUZEIRO DO SUL 2024-04-27 10:04:00
#
#               PREVENTIVA  ROTA EQUIPE EXECUTORA TIPO/SIGFI  \
# 0   MANUT PREVENTIVA  4A   3.0             EQ.3    SIGFI80
# 1   MANUT PREVENTIVA  4A  11.0             EQ.6    SIGFI45
# 2          INTERMITENCIA  12.0             EQ.5    SIGFI80
# 3          INTERMITENCIA  12.0             EQ.5    SIGFI80
# 4   MANUT PREVENTIVA  4A  11.0             EQ.6    SIGFI80
# 5          INTERMITENCIA  12.0             EQ.5    SIGFI80
# 6   MANUT PREVENTIVA  4A  10.0             EQ.4    SIGFI45
# 7   MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 8   MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 9   MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 10  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 11  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 12  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 13  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 14  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 15  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 16  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 17  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
# 18  MANUT PREVENTIVA  3A  13.0             EQ.7    SIGFI45
#
#                LATITUDE           LONGITUDE         NUMOS
# 0    -9.177375000000001  -72.69680166666667  202400032142
# 1    -9.148528333333333  -69.03839833333333  202400030765
# 2   -10.398563333333334  -69.59879666666667  202400030781
# 3   -10.472973333333334          -69.742555  202400030757
# 4    -9.149593333333334  -69.12873166666667  202400030898
# 5   -10.217361666666667  -69.40203166666667  202400030773
# 6    -8.822741666666667  -70.58537833333334  202400030872
# 7           -7.93030342        -71.61574461  202400020220
# 8           -7.93326442        -71.61631093  202400020162
# 9            -7.9277674        -71.60779041  202400018562
# 10          -7.92984651        -71.61633378  202400020204
# 11          -7.92811455        -71.60673443  202400018570
# 12          -7.93181859        -71.61182818  202400020196
# 13          -7.93028275        -71.60578334  202400018588
# 14          -7.92715557         -71.5952373  202400018604
# 15          -7.92971181        -71.61625052  202400020212
# 16           -7.9325331        -71.62251969  202400020238
# 17          -7.92739548        -71.60299037  202400018596
# 18          -7.93167951        -71.61166639  202400020188

# %%
# Salvando a planilha( .xlsx)
dataframe_excel = pd.ExcelWriter(r"D:\OEM\output\1ºtrache_intebras_ac_preventiva_lote17_3ªremessa_2024.xlsx")
lote.to_excel(dataframe_excel, index=False)
dataframe_excel.close()
